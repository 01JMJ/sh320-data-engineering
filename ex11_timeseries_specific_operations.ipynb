# %% [markdown]
# ## <strong> 13. 시계열 전용 연산

# %% [markdown]
# 필요한 라이브러리: ```yfinance```, ```pandas_datareader```

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\minjun\anaconda3\lib\site-packages (0.2.60)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (0.10.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\minjun\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\minjun\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\minjun\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\minjun\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\minjun\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\minjun\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\minjun\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\minjun\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\minjun\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\minjun\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\minjun\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
import yfinance as yf
import pandas as pd
from matplotlib import pyplot as plt

# %%
# 구글 주식 데이터 로딩
goog = yf.download("GOOG", start="2004-01-01", end="2024-12-31")
goog.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          GOOG      GOOG      GOOG      GOOG       GOOG
# Date
# 2004-08-19  2.487352  2.579567  2.378775  2.478922  897427216
# 2004-08-20  2.684922  2.704009  2.491318  2.503960  458857488
# 2004-08-23  2.711942  2.813082  2.703266  2.745408  366857939
# 2004-08-24  2.599647  2.766478  2.567421  2.757554  306396159
# 2004-08-25  2.627658  2.677238  2.575105  2.601877  184645512

# %%
# [+] 종가(Close) 데이터만 사용하기
goog = goog['Close']
goog
# Out:
# Ticker            GOOG
# Date
# 2004-08-19    2.487352
# 2004-08-20    2.684922
# 2004-08-23    2.711942
# 2004-08-24    2.599647
# 2004-08-25    2.627658
# ...                ...
# 2024-12-23  195.766968
# 2024-12-24  197.345184
# 2024-12-26  196.875717
# 2024-12-27  193.819183
# 2024-12-30  192.470734
#
# [5126 rows x 1 columns]

# %%
# [+] Lineplot 시각화
goog.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### <strong> 리샘플링(Resampling)
# + ```resample()```: 빈도를 기준으로 집계 연산
# + ```asfreq()```: 빈도 단위 별 데이터 선택

# %%
# [+] 다운샘플링: resample()
goog_downsampled = goog.resample('M').mean()
goog_downsampled
# Out:
# C:\Users\minjun\AppData\Local\Temp\ipykernel_18588\3007898505.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   goog_downsampled = goog.resample('M').mean()
# Ticker            GOOG
# Date
# 2004-08-31    2.609370
# 2004-09-30    2.806814
# 2004-10-31    3.798477
# 2004-11-30    4.399970
# 2004-12-31    4.505938
# ...                ...
# 2024-08-31  164.728803
# 2024-09-30  158.933696
# 2024-10-31  166.526794
# 2024-11-30  174.757919
# 2024-12-31  187.922449
#
# [245 rows x 1 columns]

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))
goog.plot(label='original', ax=ax[0])
ax[0].legend()
goog_downsampled.plot(label='downsampled', ax=ax[1])
ax[1].legend()
plt.tight_layout()

# %%
# [+] 다운샘플링: asfreq()
goog_downsampled = goog.asfreq('M')
print(goog_downsampled)

goog_downsampled.plot()
# Out:
# C:\Users\minjun\AppData\Local\Temp\ipykernel_18588\2305263628.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   goog_downsampled = goog.asfreq('M')
# Ticker            GOOG
# Date
# 2004-08-31    2.537673
# 2004-09-30    3.212684
# 2004-10-31         NaN
# 2004-11-30    4.511145
# 2004-12-31    4.779117
# ...                ...
# 2024-07-31  172.529846
# 2024-08-31         NaN
# 2024-09-30  166.810501
# 2024-10-31  172.298019
# 2024-11-30         NaN
#
# [244 rows x 1 columns]
# <Axes: xlabel='Date'>

# %%
# [+] 업샘플링: resample()
goog_upsampled = goog.resample('12h').mean()
print(goog_upsampled)
# Out:
# Ticker                     GOOG
# Date
# 2004-08-19 00:00:00    2.487352
# 2004-08-19 12:00:00         NaN
# 2004-08-20 00:00:00    2.684922
# 2004-08-20 12:00:00         NaN
# 2004-08-21 00:00:00         NaN
# ...                         ...
# 2024-12-28 00:00:00         NaN
# 2024-12-28 12:00:00         NaN
# 2024-12-29 00:00:00         NaN
# 2024-12-29 12:00:00         NaN
# 2024-12-30 00:00:00  192.470734
#
# [14877 rows x 1 columns]

# %% [markdown]
# #### <strong> 시프팅(Shifting)
# + ```shift(periods)``` : ```periods``` 값 만큼 시계열 이동

# %%
# [+] 900일 뒤로 시프팅 적용
goog_shifted = ...
goog_shifted

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))

# Legends and annotations
local_max = pd.to_datetime('2007-11-05')
offset = pd.Timedelta(900, 'D')

goog.plot(label='original', ax=ax[0])
ax[0].legend()
ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
ax[0].axvline(local_max, alpha=0.3, color='red')

goog_shifted.plot(label='shifted 900 days', ax=ax[1])
ax[1].legend()
ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
ax[1].axvline(local_max + offset, alpha=0.3, color='red')

plt.tight_layout()

# %%
# shifting 응용: 주가 변화율 계산
goog_shifted = goog.shift(periods = 1) # [+] 시프팅
(goog - goog_shifted ) / goog_shifted # [+] 주가 변화율 계산
# Out:
# Ticker          GOOG
# Date
# 2004-08-19       NaN
# 2004-08-20  0.079430
# 2004-08-23  0.010064
# 2004-08-24 -0.041408
# 2004-08-25  0.010775
# ...              ...
# 2024-12-23  0.015703
# 2024-12-24  0.008062
# 2024-12-26 -0.002379
# 2024-12-27 -0.015525
# 2024-12-30 -0.006957
#
# [5126 rows x 1 columns]

# %%
# shifting 응용: 차분 시계열 구하기
goog_diff = goog- goog_shifted  # [+] 차분
print(goog_diff)

goog_diff.plot()
# Out:
# Ticker          GOOG
# Date
# 2004-08-19       NaN
# 2004-08-20  0.197570
# 2004-08-23  0.027020
# 2004-08-24 -0.112295
# 2004-08-25  0.028012
# ...              ...
# 2024-12-23  3.026550
# 2024-12-24  1.578217
# 2024-12-26 -0.469467
# 2024-12-27 -3.056534
# 2024-12-30 -1.348450
#
# [5126 rows x 1 columns]
# <Axes: xlabel='Date'>

# %% [markdown]
# #### <strong> 윈도잉(Windowing)

# %%
# [+] 365일 단위 윈도잉
goog_rolled = goog.rolling(window=365)  # [+] 윈도잉
print(goog_rolled)

goog_rolled.mean().plot()
# Out:
# Rolling [window=365,center=False,axis=0,method=single]
# <Axes: xlabel='Date'>

# %%
data = pd.DataFrame({'input': goog.values.flatten(),
                     # moving average
                     'one-year rolling_mean': goog_rolled.mean().values.flatten(), 
                     # standard deviation
                     'one-year rolling_std': goog_rolled.std().values.flatten()}, index=goog.index)
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)
